# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderAvocone/Project/blob/master/MonteCarlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Rechnernutzung Übungsaufgabe 3**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**a)**

# %%
import matplotlib.pyplot as plt
import numpy as np


def vdichte(x):
    return 3./8.*(1+x**2)

n = 10000
under_curve = []

#Verwerfungsmethode
for i in range(n):
    x_wert = np.random.rand()*2-1   # -1 < x < 1 da x_wert [0,1)
    y_wert = np.random.rand()
    if vdichte1(x_wert) > y_wert:   
        under_curve.append(x_wert)
        

        
x1 = np.linspace(-1,1,100)    
plt.hist(under_curve, bins=20, density=True, alpha = 0.7, label = "Verteilung")
plt.plot(x1,vdichte1(x1),color = "r", alpha = 0.7, label = "Verteilungsdichte")
plt.legend()

# %% [markdown]
# #**b)**

# %%
def cauchy(x):
    return 1/np.pi *(1/(1+x**2))

#Transformationsmethode: f(x) --> F(x) --> Umkehrfunktion von F(x)
def ctransform(x):
    return np.tan(x)


list=[]
for i in range(n):
    z=np.random.rand()
    #range der zufallszahl
    if z > 0.01 and z<0.99:   #Warum geht z<1. nicht?
        list.append(np.pi*(z-0.5))


x2 = np.linspace(-15,15,100)
plt.hist(ctransform(list),bins=100,density=True, alpha = 0.5, label = "Transform")
plt.plot(x2,cauchy(x2), alpha = 0.7, color = "r", label = "Cauchy")
plt.legend()
